# %% [markdown]
# # Anomaly Detection Notebook
#
# This notebook is now a clean project walkthrough.
#
# The actual production pipeline lives in `src/inference.py` and `src/sort.py`. This notebook is only for setup notes and a simple smoke-test entry point.

# %%
## Setup

Install dependencies from `requirements.txt` in your virtual environment. Avoid installing packages directly from notebook cells unless you are debugging the environment.

# %%
## Optional environment notes

If you need extra packages, install them in the terminal so the project stays reproducible.

# %%
import os
from pathlib import Path

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
project_root = Path.cwd()
print('Project root:', project_root)

# %%
model_path = project_root / 'models' / 'LRCN_model.h5'
video_path = project_root / 'data' / 'input.mp4'
output_path = project_root / 'outputs' / 'dryrun.mp4'

print('Model path:', model_path)
print('Video path:', video_path)
print('Output path:', output_path)

# %%
## Project entry points

Use `src/inference.py` for the real pipeline. It reads paths from `configs/config.yaml` and supports `--dry_run` for a lightweight smoke test.

# %%
## Tracker

The SORT tracker now lives in `src/sort.py`. Import it from there instead of the old notebook scratch code.

# %%
## Model path

Use the model path from `configs/config.yaml` or pass `--model` on the command line. The notebook should not hardcode local drive paths.

# %%
import subprocess
import sys
from pathlib import Path

output_path = Path("outputs/notebook_dryrun.mp4")
output_path.parent.mkdir(parents=True, exist_ok=True)

subprocess.run([
    sys.executable,
    "src/inference.py",
    "--dry_run",
    "--output",
    str(output_path),
], check=True)
print(f"Notebook smoke test wrote {output_path}")
# Out:
# 0: 384x640 3 persons, 14.5ms
# Speed: 0.8ms preprocess, 14.5ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 25.3ms
# Speed: 2.3ms preprocess, 25.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 30.1ms
# Speed: 0.0ms preprocess, 30.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 22.5ms
# Speed: 5.5ms preprocess, 22.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 26.0ms
# Speed: 2.3ms preprocess, 26.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 24.5ms
# Speed: 1.2ms preprocess, 24.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 26.8ms
# Speed: 0.0ms preprocess, 26.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 32.3ms
# ...
